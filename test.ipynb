# %%
print("Hello Wolrd")
# Out:
# Hello Wolrd

# %%
# Connecting to mongo
from dotenv import load_dotenv
import os

load_dotenv()
URI = os.getenv("MONGO_URI")
URI
# Out:
# 'mongodb+srv://princekumar9837771886_db_user:Prince@983777@cluster0.qzzyfmr.mongodb.net/?appName=Cluster0'

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri="mongodb+srv://princekumar9837771886_db_user:9837771886@cluster0.qzzyfmr.mongodb.net/?appName=Cluster0"
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# ---------------------------------------------------------------------------
# InvalidURI                                Traceback (most recent call last)
# Cell In[8], line 5
#       1 from pymongo.mongo_client import MongoClient
#       2 from pymongo.server_api import ServerApi
#       3
#       4 uri="mongodb+srv://princekumar9837771886_db_user:9837771886@cluster0.qzzyfmr.mongodb.net/?appName=Cluster0"
# ----> 5 client = MongoClient(URI, server_api=ServerApi('1'))
#       6
#       7 # Send a ping to confirm a successful connection
#       8 try:
#
# File e:\Projects\Reinforcement-Learning\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:804, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     799 for entity in self._host:
#     800     # A hostname can only include a-z, 0-9, '-' and '.'. If we find a '/'
#     801     # it must be a URI,
#     802     # https://en.wikipedia.org/wiki/Hostname#Restrictions_on_valid_host_names
#     803     if "/" in entity:
# --> 804         res = _validate_uri(
#     805             entity,
#     806             port,
#     807             validate=True,
#     808             warn=True,
#     809             normalize=False,
#     810             srv_max_hosts=srv_max_hosts,
#     811         )
#     812         is_srv = entity.startswith(SRV_SCHEME)
#     813         self._seeds.update(res["nodelist"])
#
# File e:\Projects\Reinforcement-Learning\.venv\Lib\site-packages\pymongo\uri_parser_shared.py:563, in _validate_uri(uri, default_port, validate, warn, normalize, srv_max_hosts)
#     561 if "@" in host_part:
#     562     userinfo, _, hosts = host_part.rpartition("@")
# --> 563     user, passwd = parse_userinfo(userinfo)
#     564 else:
#     565     hosts = host_part
#
# File e:\Projects\Reinforcement-Learning\.venv\Lib\site-packages\pymongo\uri_parser_shared.py:136, in parse_userinfo(userinfo)
#     126 """Validates the format of user information in a MongoDB URI.
#     127 Reserved characters that are gen-delimiters (":", "/", "?", "#", "[",
#     128 "]", "@") as per RFC 3986 must be escaped.
#    (...)    133 :param userinfo: A string of the form <username>:<password>
#     134 """
#     135 if "@" in userinfo or userinfo.count(":") > 1 or _unquoted_percent(userinfo):
# --> 136     raise InvalidURI(
#     137         "Username and password must be escaped according to "
#     138         "RFC 3986, use urllib.parse.quote_plus"
#     139     )
#     141 user, _, passwd = userinfo.partition(":")
#     142 # No password is expected with GSSAPI authentication.
#
# InvalidURI: Username and password must be escaped according to RFC 3986, use urllib.parse.quote_plus
